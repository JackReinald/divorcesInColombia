# %%
import pandas as pd

df=pd.read_csv("datos_twitter.csv")
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df.loc[5:7, ["id", "user"]]
# Out:
#        id           user
# 5  183726  mateusmartins
# 6  183727  leonardokuffo
# 7  183728    pedrojuarez

# %%
df.iloc[5:8, [0,6]]
# Out:
#        id           user
# 5  183726  mateusmartins
# 6  183727  leonardokuffo
# 7  183728    pedrojuarez

# %%
df.iloc[25,5]
# Out:
# 'MEXICO'

# %%
df.loc[25, "country"]
# Out:
# 'MEXICO'

# %%
df[["country", "id"]]
# Out:
#     country      id
# 0   ECUADOR  183721
# 1    BRASIL  183722
# 2    MEXICO  183723
# 3   ECUADOR  183724
# 4    MEXICO  183725
# 5    BRASIL  183726
# 6   ECUADOR  183727
# 7    MEXICO  183728
# 8    MEXICO  183729
# 9    BRASIL  183730
# 10   BRASIL  183731
# 11   BRASIL  183732
# 12  ECUADOR  183733
# 13  ECUADOR  183734
# 14   MEXICO  183735
# 15   MEXICO  183736
# 16   BRASIL  183737
# 17   MEXICO  183738
# 18  ECUADOR  183739
# 19   BRASIL  183740
# 20  ECUADOR  183741
# 21  ECUADOR  183742
# 22   BRASIL  183743
# 23   BRASIL  183744
# 24   BRASIL  183745
# 25   MEXICO  183746
# 26   BRASIL  183747

# %%
df[df["favorites"] >= 490]
# Out:
#        id                                          full_text  favorites  \
# 1  183722                Today we commemorate and MNML Case.      500.0
# 5  183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
#
#    retweets  mentions country           user  followers  followees
# 1      21.0       NaN  BRASIL  mateusmartins      982.0       1822
# 5      70.0       6.0  BRASIL  mateusmartins      982.0       1822

# %%
df[df["favorites"] >= 490][["country", "id"]]
# Out:
#   country      id
# 1  BRASIL  183722
# 5  BRASIL  183726

# %%
df[df["country"] == "BRASIL"]
# Out:
#         id                                          full_text  favorites  \
# 1   183722                Today we commemorate and MNML Case.      500.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 16  183737                                              PIC!!      346.0
# 19  183740                        Programming is a hot topic!      133.0
# 22  183743                         Amazing video by Leonardo!      432.0
# 23  183744                                        Thanks man!      430.0
# 24  183745          There is nothing better than programming!      424.0
# 26  183747  I do not know if i like programming or other t...      318.0
#
#     retweets  mentions country             user  followers  followees
# ...

# %%
df[df.retweets == 21]
# Out:
#        id                            full_text  favorites  retweets  mentions  \
# 1  183722  Today we commemorate and MNML Case.      500.0      21.0       NaN
#
#   country           user  followers  followees
# 1  BRASIL  mateusmartins      982.0       1822

# %%
copia = df.rename(columns={"full_text": "fullt 2text"})
copia
# Out:
#         id                                        fullt 2text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df[((df.country == "BRASIL") | (df.country == "MEXICO")) & (df.mentions <= 30)]
# Out:
#         id                                          full_text  favorites  \
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 14  183735                             Buy this product NOW!!      418.0
# 15  183736  I have one is best color gradients: Just relea...      361.0
# 16  183737                                              PIC!!      346.0
# 17  183738                             hmmm feeling bad today      296.0
# ...

# %%
df.full_text.str.contains("love")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# Name: full_text, dtype: bool
