# %%
import pandas as pd

df = pd.read_csv("datos_twitter.csv")   # Se guardan los datos en la variable df (data frame)
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
resumenHead = df.head()   # Muestra la cantidad de filas dentro del paréntesis (por defecto son 5)

# %%
resumenHead
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 3      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 4     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
resumenTail = df.tail(9)    # Muestra las últimas filas indicadas dentro paréntesis (por defecto, 5)

# %%
resumenTail
# Out:
#         id                                          full_text  favorites  \
# 18  183739                          not feeling god right now      315.0
# 19  183740                        Programming is a hot topic!      133.0
# 20  183741                            Programming? i love it!       92.0
# 21  183742                                            WHAT???      255.0
# 22  183743                         Amazing video by Leonardo!      432.0
# 23  183744                                        Thanks man!      430.0
# 24  183745          There is nothing better than programming!      424.0
# 25  183746                                           BORED AF      488.0
# 26  183747  I do not know if i like programming or other t...      318.0
#
#     retweets  mentions  country             user  followers  followees
# 18      26.0      10.0  ECUADOR     galocastillo      332.0        378
# 19     145.0      15.0   BRASIL       lucasperes       82.0        351
# ...

# %%
resumenCustom = df[10:15]
resumenCustom
# Out:
#         id                                          full_text  favorites  \
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
# 13  183734                             I cannot believe this!       50.0
# 14  183735                             Buy this product NOW!!      418.0
#
#     retweets  mentions  country             user  followers  followees
# 10     111.0       8.0   BRASIL    mateusmartins      982.0       1822
# 11      44.0      19.0   BRASIL    mateusmartins      982.0       1822
# 12      69.0      10.0  ECUADOR    leonardokuffo      389.0        258
# 13      24.0      22.0  ECUADOR    leonardokuffo      389.0        258
# 14      24.0       2.0   MEXICO  gabrielcarvajal       21.0       2721

# %%
resumenIloc = df.iloc[10:15]
resumenIlocPro = df.iloc[[10,15], [0,1]]

# %%
resumenIloc
# Out:
#         id                                          full_text  favorites  \
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
# 13  183734                             I cannot believe this!       50.0
# 14  183735                             Buy this product NOW!!      418.0
#
#     retweets  mentions  country             user  followers  followees
# 10     111.0       8.0   BRASIL    mateusmartins      982.0       1822
# 11      44.0      19.0   BRASIL    mateusmartins      982.0       1822
# 12      69.0      10.0  ECUADOR    leonardokuffo      389.0        258
# 13      24.0      22.0  ECUADOR    leonardokuffo      389.0        258
# 14      24.0       2.0   MEXICO  gabrielcarvajal       21.0       2721

# %%
resumenIlocPro
# Out:
#         id                                          full_text
# 10  183731  Great to advertise during the year I tweeted a...
# 15  183736  I have one is best color gradients: Just relea...

# %%
# Calcular las estadisticas descriptivas
df.describe()
# Out:
#                   id   favorites    retweets   mentions   followers  \
# count      27.000000   26.000000   26.000000  26.000000   26.000000
# mean   183734.000000  280.538462   80.000000  15.423077  352.807692
# std         7.937254  153.377242   40.303846   9.596554  375.319493
# min    183721.000000   23.000000   21.000000   1.000000   12.000000
# 25%    183727.500000  139.250000   45.500000   8.250000   21.000000
# 50%    183734.000000  305.500000   79.000000  16.000000  332.000000
# 75%    183740.500000  422.500000  110.750000  23.500000  389.000000
# max    183747.000000  500.000000  146.000000  29.000000  982.000000
#
#          followees
# count    27.000000
# mean   1190.185185
# std    1965.735995
# min     129.000000
# 25%     258.000000
# 50%     351.000000
# 75%    1822.000000
# max    9918.000000

# %%
# Eliminar las filas que tienen valores NaN (Not a Number)
dfSinNaN = df.dropna()

# %%
# Rellenar los valores NaN con un valor específico
df.fillna("ñero")
# Out:
#         id                                          full_text favorites  \
# 0   183721  Flying home to run down from the power to comi...      23.0
# 1   183722                Today we commemorate and MNML Case.     500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…     190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...     131.0
# 4   183725                                    Welcome back! 🙌     113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!     492.0
# 6   183727                                 80's & friends! ✈️     158.0
# 7   183728  Thank you guess how did I feel somewhat offend...      ñero
# 8   183729        OnePlus 8 international giveaway classifies     198.0
# 9   183730                Here it is.. Retweet this desperate     272.0
# 10  183731  Great to advertise during the year I tweeted a...      43.0
# 11  183732  Its been in love with the game with the origin...     349.0
# ...

# %%
df[["followers", "user"]]
# Out:
#     followers             user
# 0       389.0    leonardokuffo
# 1       982.0    mateusmartins
# 2        12.0      pedrojuarez
# 3       332.0     galocastillo
# 4        12.0      pedrojuarez
# 5       982.0    mateusmartins
# 6       389.0    leonardokuffo
# 7        12.0      pedrojuarez
# 8        12.0      pedrojuarez
# 9       982.0    mateusmartins
# 10      982.0    mateusmartins
# 11      982.0    mateusmartins
# 12      389.0    leonardokuffo
# 13      389.0    leonardokuffo
# 14       21.0  gabrielcarvajal
# 15       12.0      pedrojuarez
# 16       82.0       lucasperes
# 17       21.0  gabrielcarvajal
# 18      332.0     galocastillo
# 19       82.0       lucasperes
# 20      332.0     galocastillo
# 21      332.0     galocastillo
# 22       82.0       lucasperes
# 23        NaN       lucasperes
# 24       82.0       lucasperes
# 25       21.0  gabrielcarvajal
# 26      928.0  isabelladasilva

# %%
df.iloc[[1, 26]]
# Out:
#         id                                          full_text  favorites  \
# 1   183722                Today we commemorate and MNML Case.      500.0
# 26  183747  I do not know if i like programming or other t...      318.0
#
#     retweets  mentions country             user  followers  followees
# 1       21.0       NaN  BRASIL    mateusmartins      982.0       1822
# 26      58.0      20.0  BRASIL  isabelladasilva      928.0       9918

# %%
df.iloc[1:13]
# Out:
#         id                                          full_text  favorites  \
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
#
# ...

# %%
# Mostrar las filas y columnnas específicas
df.loc[ [1,26], ["user", "retweets"] ]
# Out:
#                user  retweets
# 1     mateusmartins      21.0
# 26  isabelladasilva      58.0

# %%
# Filtrar por condición
df[ (df["followers"] > 100) and (df["country"] == "ECUADOR") ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16616\2971872401.py in ?()
#       1 # Filtrar por condición
# ----> 2 df[ (df["followers"] > 100) and (df["country"] == "ECUADOR") ]
#
# c:\Users\Administrador\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#Eliminar una columna
df.drop("full_text", axis="columns")
# Out:
#         id  favorites  retweets  mentions  country             user  \
# 0   183721       23.0       NaN      10.0  ECUADOR    leonardokuffo
# 1   183722      500.0      21.0       NaN   BRASIL    mateusmartins
# 2   183723      190.0     123.0       6.0   MEXICO      pedrojuarez
# 3   183724      131.0      76.0       3.0  ECUADOR     galocastillo
# 4   183725      113.0     130.0       9.0   MEXICO      pedrojuarez
# 5   183726      492.0      70.0       6.0   BRASIL    mateusmartins
# 6   183727      158.0      40.0      22.0  ECUADOR    leonardokuffo
# 7   183728        NaN      50.0      10.0   MEXICO      pedrojuarez
# 8   183729      198.0      82.0      26.0   MEXICO      pedrojuarez
# 9   183730      272.0      92.0      29.0   BRASIL    mateusmartins
# 10  183731       43.0     111.0       8.0   BRASIL    mateusmartins
# 11  183732      349.0      44.0      19.0   BRASIL    mateusmartins
# 12  183733      467.0      69.0      10.0  ECUADOR    leonardokuffo
# ...

# %%
# Eliminar la fila especificada
df.drop(0, axis="rows")
# Out:
#         id                                          full_text  favorites  \
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
# ...
